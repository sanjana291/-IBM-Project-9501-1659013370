# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='h3AHNJY4VCQGhKEgHFx7vHkE4U-oZXVIQTpnUooAz0JW',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

bucket = 'webphishingdetection-donotdelete-pr-6zbcmivasyvn2m'
object_key = 'dataset_website.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df = pd.read_csv(body)
df.head()
# Out:
#    index  having_IPhaving_IP_Address  URLURL_Length  Shortining_Service  \
# 0      1                          -1              1                   1
# 1      2                           1              1                   1
# 2      3                           1              0                   1
# 3      4                           1              0                   1
# 4      5                           1              0                  -1
#
#    having_At_Symbol  double_slash_redirecting  Prefix_Suffix  \
# 0                 1                        -1             -1
# 1                 1                         1             -1
# 2                 1                         1             -1
# 3                 1                         1             -1
# 4                 1                         1             -1
#
#    having_Sub_Domain  SSLfinal_State  Domain_registeration_length  ...  \
# 0                 -1              -1                           -1  ...
# ...

# %%
# Import Required Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
df.shape
# Out:
# (11055, 32)

# %%
df.isnull().sum()
# Out:
# index                          0
# having_IPhaving_IP_Address     0
# URLURL_Length                  0
# Shortining_Service             0
# having_At_Symbol               0
# double_slash_redirecting       0
# Prefix_Suffix                  0
# having_Sub_Domain              0
# SSLfinal_State                 0
# Domain_registeration_length    0
# Favicon                        0
# port                           0
# HTTPS_token                    0
# Request_URL                    0
# URL_of_Anchor                  0
# Links_in_tags                  0
# SFH                            0
# Submitting_to_email            0
# Abnormal_URL                   0
# Redirect                       0
# on_mouseover                   0
# RightClick                     0
# popUpWidnow                    0
# Iframe                         0
# age_of_domain                  0
# DNSRecord                      0
# web_traffic                    0
# Page_Rank                      0
# ...

# %%
df.describe()
# Out:
#               index  having_IPhaving_IP_Address  URLURL_Length  \
# count  11055.000000                11055.000000   11055.000000
# mean    5528.000000                    0.313795      -0.633198
# std     3191.447947                    0.949534       0.766095
# min        1.000000                   -1.000000      -1.000000
# 25%     2764.500000                   -1.000000      -1.000000
# 50%     5528.000000                    1.000000      -1.000000
# 75%     8291.500000                    1.000000      -1.000000
# max    11055.000000                    1.000000       1.000000
#
#        Shortining_Service  having_At_Symbol  double_slash_redirecting  \
# count        11055.000000      11055.000000              11055.000000
# mean             0.738761          0.700588                  0.741474
# std              0.673998          0.713598                  0.671011
# min             -1.000000         -1.000000                 -1.000000
# ...

# %%
df.Result.unique()
# Out:
# array([-1,  1])

# %%
# Find the outliers and replace them outliers
plt.figure(figsize=(32,32))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# Visuvalition
sns.boxplot(df.Shortining_Service)
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shortining_Service'>

# %%
p99=df.URLURL_Length.quantile(.80)
df['URLURL_Length']=np.where(df['URLURL_Length']>p99,p99,df['URLURL_Length'])

# %%
sns.boxplot(df.URLURL_Length)
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='URLURL_Length'>

# %%
p01=df.Shortining_Service.quantile(.15)
df['Shortining_Service']=np.where(df['Shortining_Service']<p01,p01,df['Shortining_Service'])

# %%
sns.boxplot(df.Shortining_Service)
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shortining_Service'>

# %%
# Splitting data as independent and dependent
# Removing index column in independent dataset
x=df.iloc[:,1:31]
y=df.Result

# %%
#Scale the independent variables
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
xscale=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
#  Split the data into training and testing
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(xscale,y,test_size=.2,random_state=10)

# %%
# model building
from sklearn.linear_model import LogisticRegression
model1=LogisticRegression()

# %%
model1.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
trainpred1=model1.predict(xtrain)
testpred1=model1.predict(xtest)

# %%
# evaluation metics
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
pd.crosstab(ytest,testpred1)
# Out:
# col_0    -1     1
# Result
# -1      867    94
#  1       62  1188

# %%
accuracy_score(ytest,testpred1)
# Out:
# 0.9294436906377205

# %%
accuracy_score(ytrain,trainpred1)
# Out:
# 0.9286521935775667

# %%
print(classification_report(ytest,testpred1))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.92      0.91      0.92       961
#            1       0.93      0.94      0.94      1250
#
#     accuracy                           0.93      2211
#    macro avg       0.93      0.93      0.93      2211
# weighted avg       0.93      0.93      0.93      2211

# %%
from sklearn.ensemble import RandomForestClassifier
model2=RandomForestClassifier()

# %%
model2.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
trainpred2=model2.predict(xtrain)
testpred2=model2.predict(xtest)

# %%
print(confusion_matrix(ytest,testpred2))
# Out:
# [[ 924   37]
#  [  24 1226]]

# %%
print(accuracy_score(ytest,testpred2))
print(accuracy_score(ytrain,trainpred2))
# Out:
# 0.9724106739032112
# 0.9893713251922207

# %%
print(classification_report(ytest,testpred2))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.97      0.96      0.97       961
#            1       0.97      0.98      0.98      1250
#
#     accuracy                           0.97      2211
#    macro avg       0.97      0.97      0.97      2211
# weighted avg       0.97      0.97      0.97      2211

# %%
pd.crosstab(ytest,testpred2)
# Out:
# col_0    -1     1
# Result
# -1      924    37
#  1       24  1226

# %% [markdown]
# ### IBM Deployment

# %%
# !pip install -U ibm-watson-machine-Learning

# %%
from ibm_watson_machine_learning import APIClient
import json

# %%
# Authentication and Set Space
wml_credential={
    "apikey":"K09NTcGFskKVbpURhofU4UwPIAb3wPOQn-uK6NBKK6b6",
    "url":"https://us-south.ml.cloud.ibm.com"
}

# %%
wml_client = APIClient(wml_credential)

# %%
wml_client.spaces.list()
# Out:
# Note: 'limit' is not provided. Only first 50 records will be displayed if the number of records exceed 50
# ------------------------------------  ----------------------  ------------------------
# ID                                    NAME                    CREATED
# 9c40b500-6c1c-4170-b6e4-081924ecaa3a  Web Phishing Detection  2022-11-12T21:05:28.616Z
# ------------------------------------  ----------------------  ------------------------

# %%
SPACE_ID="9c40b500-6c1c-4170-b6e4-081924ecaa3a"

# %%
wml_client.set.default_space(SPACE_ID)
# Out:
# 'SUCCESS'

# %%
wml_client.software_specifications.list(500)
# Out:
# -------------------------------  ------------------------------------  ----
# NAME                             ASSET_ID                              TYPE
# default_py3.6                    0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# kernel-spark3.2-scala2.12        020d69ce-7ac1-5e68-ac1a-31189867356a  base
# pytorch-onnx_1.3-py3.7-edt       069ea134-3346-5748-b513-49120e15d288  base
# scikit-learn_0.20-py3.6          09c5a1d0-9c1e-4473-a344-eb7b665ff687  base
# spark-mllib_3.0-scala_2.12       09f4cff0-90a7-5899-b9ed-1ef348aebdee  base
# pytorch-onnx_rt22.1-py3.9        0b848dd4-e681-5599-be41-b5f6fccc6471  base
# ai-function_0.1-py3.6            0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base
# shiny-r3.6                       0e6e79df-875e-4f24-8ae9-62dcc2148306  base
# tensorflow_2.4-py3.7-horovod     1092590a-307d-563d-9b62-4eb7d64b3f22  base
# pytorch_1.1-py3.6                10ac12d6-6b30-4ccd-8392-3e922c096a92  base
# ...

# %%
# Save and Deploy the model
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
MODEL_NAME = 'Web Phishing Detection'
DEPLOYMENT_NAME = 'The Web Phishing Detection'
DEMO_MODEL= model2

# %%
# set python version
software_spec_uid= wml_client.software_specifications.get_id_by_name('runtime-22.1-py3.9')

# %%
# setup model meta
model_probs= {
    wml_client.repository.ModelMetaNames.NAME: MODEL_NAME,
    wml_client.repository.ModelMetaNames.TYPE: 'scikit-learn_1.0',
    wml_client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid
}

# %%
# Setup model
model_details=wml_client.repository.store_model(
    model=DEMO_MODEL,
    meta_props=model_probs,
    training_data=xtrain,
    training_target=ytrain
)

# %%
model_details
# Out:
# {'entity': {'hybrid_pipeline_software_specs': [],
#   'label_column': 'Result',
#   'schemas': {'input': [{'fields': [{'name': 'having_IPhaving_IP_Address',
#        'type': 'float64'},
#       {'name': 'URLURL_Length', 'type': 'float64'},
#       {'name': 'Shortining_Service', 'type': 'float64'},
#       {'name': 'having_At_Symbol', 'type': 'float64'},
#       {'name': 'double_slash_redirecting', 'type': 'float64'},
#       {'name': 'Prefix_Suffix', 'type': 'float64'},
#       {'name': 'having_Sub_Domain', 'type': 'float64'},
#       {'name': 'SSLfinal_State', 'type': 'float64'},
#       {'name': 'Domain_registeration_length', 'type': 'float64'},
#       {'name': 'Favicon', 'type': 'float64'},
#       {'name': 'port', 'type': 'float64'},
#       {'name': 'HTTPS_token', 'type': 'float64'},
#       {'name': 'Request_URL', 'type': 'float64'},
#       {'name': 'URL_of_Anchor', 'type': 'float64'},
#       {'name': 'Links_in_tags', 'type': 'float64'},
# ...

# %%
model_id = wml_client.repository.get_model_id(model_details)
model_id
# Out:
# '8e2f6b3b-9eba-4475-a9a1-7f983322765e'

# %%
# set meta
deployment_props={
    wml_client.deployments.ConfigurationMetaNames.NAME:DEPLOYMENT_NAME,
    wml_client.deployments.ConfigurationMetaNames.ONLINE: {}
}

# %%
#deploy
deployment=wml_client.deployments.create(
    artifact_uid=model_id,
    meta_props=deployment_props
)
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '8e2f6b3b-9eba-4475-a9a1-7f983322765e' started
#
# #######################################################################################
#
#
# initializing
# Note: online_url is deprecated and will be removed in a future release. Use serving_urls instead.
#
# ready
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='6b7d2b7c-2ae3-48b2-89e0-20c59173e7c3'
# ------------------------------------------------------------------------------------------------
